# %%
# !python /home/jorgetbm/SynthSeg/setup.py install
# Out:
# []
# running install
# running bdist_egg
# running egg_info
# creating SynthSeg.egg-info
# writing SynthSeg.egg-info/PKG-INFO
# writing dependency_links to SynthSeg.egg-info/dependency_links.txt
# writing requirements to SynthSeg.egg-info/requires.txt
# writing top-level names to SynthSeg.egg-info/top_level.txt
# writing manifest file 'SynthSeg.egg-info/SOURCES.txt'
# reading manifest file 'SynthSeg.egg-info/SOURCES.txt'
# writing manifest file 'SynthSeg.egg-info/SOURCES.txt'
# installing library code to build/bdist.linux-x86_64/egg
# running install_lib
# ...
#
# creating build
# creating build/bdist.linux-x86_64
# creating build/bdist.linux-x86_64/egg
# creating build/bdist.linux-x86_64/egg/EGG-INFO
# copying SynthSeg.egg-info/PKG-INFO -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying SynthSeg.egg-info/SOURCES.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying SynthSeg.egg-info/dependency_links.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# ...

# %%
# !python /home/jorgetbm/SynthSeg/scripts/commands/SynthSeg_predict.py --i /home/jorgetbm/atlas/altas5SyMNet.nii --o /home/jorgetbm/atlas/seg_altas5SyMNet.nii
# Out:
# Using TensorFlow backend.
#
# SynthSeg 2.0
#
# using 1 thread
# 2023-07-07 19:33:22.107291: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2023-07-07 19:33:22.134313: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:1006] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-07-07 19:33:22.134865: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1618] Found device 0 with properties:
# name: TITAN RTX major: 7 minor: 5 memoryClockRate(GHz): 1.77
# pciBusID: 0000:01:00.0
# 2023-07-07 19:33:22.134898: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:1006] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-07-07 19:33:22.135419: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1618] Found device 1 with properties:
# ...
