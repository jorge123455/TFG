# %%
# !git clone https://github.com/cwmok/LapIRN
# Out:
# Cloning into 'LapIRN'...
# remote: Enumerating objects: 133, done.
# remote: Counting objects: 100% (88/88), done.
# remote: Compressing objects: 100% (44/44), done.
# remote: Total 133 (delta 52), reused 74 (delta 42), pack-reused 45
# Receiving objects: 100% (133/133), 12.34 MiB | 10.17 MiB/s, done.
# Resolving deltas: 100% (69/69), done.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import sys
print(sys.version)
# Out:
# 3.10.12 (main, Jun 11 2023, 05:26:28) [GCC 11.4.0]

# %%
# !pip install torch==1.11.0
# Out:
# Collecting torch==1.11.0
#   Downloading torch-1.11.0-cp310-cp310-manylinux1_x86_64.whl (750.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 750.6/750.6 MB 1.2 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch==1.11.0) (4.5.0)
# Installing collected packages: torch
#   Attempting uninstall: torch
#     Found existing installation: torch 2.1.0+cu118
#     Uninstalling torch-2.1.0+cu118:
#       Successfully uninstalled torch-2.1.0+cu118
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torchaudio 2.1.0+cu118 requires torch==2.1.0, but you have torch 1.11.0 which is incompatible.
# torchdata 0.7.0 requires torch==2.1.0, but you have torch 1.11.0 which is incompatible.
# torchtext 0.16.0 requires torch==2.1.0, but you have torch 1.11.0 which is incompatible.
# torchvision 0.16.0+cu118 requires torch==2.1.0, but you have torch 1.11.0 which is incompatible.
# Successfully installed torch-1.11.0

# %%
# !pip install numpy
# Out:
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (1.23.5)

# %%
# !pip install nibabel
# Out:
# Requirement already satisfied: nibabel in /usr/local/lib/python3.10/dist-packages (4.0.2)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from nibabel) (1.23.5)
# Requirement already satisfied: packaging>=17.0 in /usr/local/lib/python3.10/dist-packages (from nibabel) (23.2)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from nibabel) (67.7.2)

# %%
import nibabel as nib
import numpy as np
import os
import tensorflow as tf

# %%
imagenA = nib.load('/content/drive/MyDrive/pruebasTFG/002_S_0295_ADNI1_MPRAGE_N3-NoSkull.nii').get_fdata()
imagenA = imagenA[0:176,0:208,0:176]
imagenA.shape
print(type(imagenA))

imagenB = nib.load('/content/drive/MyDrive/pruebasTFG/002_S_0619_ADNI1_MPRAGE_N3-NoSkull.nii').get_fdata()
imagenB = imagenB[0:176,0:208,0:176]
imagenB.shape
print(type(imagenB))
# Out:
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>

# %%
pip install voxelmorph
# Out:
# Collecting voxelmorph
#   Downloading voxelmorph-0.2-py3-none-any.whl (54 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.2/54.2 kB 2.1 MB/s eta 0:00:00
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from voxelmorph) (23.2)
# Requirement already satisfied: scikit-image in /usr/local/lib/python3.10/dist-packages (from voxelmorph) (0.19.3)
# Requirement already satisfied: h5py in /usr/local/lib/python3.10/dist-packages (from voxelmorph) (3.9.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from voxelmorph) (1.23.5)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from voxelmorph) (1.11.3)
# Requirement already satisfied: nibabel in /usr/local/lib/python3.10/dist-packages (from voxelmorph) (4.0.2)
# Collecting neurite>=0.2 (from voxelmorph)
#   Downloading neurite-0.2-py3-none-any.whl (108 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 108.9/108.9 kB 4.6 MB/s eta 0:00:00
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from neurite>=0.2->voxelmorph) (1.16.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from neurite>=0.2->voxelmorph) (4.66.1)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from neurite>=0.2->voxelmorph) (3.7.1)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from neurite>=0.2->voxelmorph) (1.2.2)
# Collecting pystrum>=0.2 (from neurite>=0.2->voxelmorph)
#   Downloading pystrum-0.4.tar.gz (17 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from nibabel->voxelmorph) (67.7.2)
# Requirement already satisfied: networkx>=2.2 in /usr/local/lib/python3.10/dist-packages (from scikit-image->voxelmorph) (3.2.1)
# Requirement already satisfied: pillow!=7.1.0,!=7.1.1,!=8.3.0,>=6.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-image->voxelmorph) (9.4.0)
# Requirement already satisfied: imageio>=2.4.1 in /usr/local/lib/python3.10/dist-packages (from scikit-image->voxelmorph) (2.31.6)
# Requirement already satisfied: tifffile>=2019.7.26 in /usr/local/lib/python3.10/dist-packages (from scikit-image->voxelmorph) (2023.9.26)
# Requirement already satisfied: PyWavelets>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-image->voxelmorph) (1.4.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->neurite>=0.2->voxelmorph) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->neurite>=0.2->voxelmorph) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->neurite>=0.2->voxelmorph) (4.44.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->neurite>=0.2->voxelmorph) (1.4.5)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->neurite>=0.2->voxelmorph) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->neurite>=0.2->voxelmorph) (2.8.2)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->neurite>=0.2->voxelmorph) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->neurite>=0.2->voxelmorph) (3.2.0)
# Building wheels for collected packages: pystrum
#   Building wheel for pystrum (setup.py) ... done
#   Created wheel for pystrum: filename=pystrum-0.4-py3-none-any.whl size=19535 sha256=0809e373f65dd3f8ef7ef96090138cb2985a30ecb978a163bb6803170bc5936a
#   Stored in directory: /root/.cache/pip/wheels/aa/08/d0/914025beb5a12a855b8aafd22eeedc547198684a3f4409f66c
# Successfully built pystrum
# Installing collected packages: pystrum, neurite, voxelmorph
# Successfully installed neurite-0.2 pystrum-0.4 voxelmorph-0.2

# %%
import voxelmorph as vxm

# %%
import neurite as ne

vol_shape = (176, 208, 176)

mid_slices_imagenA = [np.take(imagenA, vol_shape[d]//2, axis=d) for d in range(3)]
mid_slices_imagenA[1] = np.rot90(mid_slices_imagenA[1], 1)
mid_slices_imagenA[2] = np.rot90(mid_slices_imagenA[2], -1)

ne.plot.slices(mid_slices_imagenA, cmaps=['gray'], do_colorbars=True);

# %%
mid_slices_imagenB = [np.take(imagenB, vol_shape[d]//2, axis=d) for d in range(3)]
mid_slices_imagenB[1] = np.rot90(mid_slices_imagenB[1], 1)
mid_slices_imagenB[2] = np.rot90(mid_slices_imagenB[2], -1)

ne.plot.slices(mid_slices_imagenB, cmaps=['gray'], do_colorbars=True);

# %%
# !python /content/LapIRN/Code/Test_LapIRN_diff_resize.py --modelpath /content/LapIRN/Model/LapIRN_diff_fea7.pth --fixed /content/drive/MyDrive/pruebasTFG/002_S_0619_ADNI1_MPRAGE_N3-NoSkull.nii --moving /content/drive/MyDrive/pruebasTFG/002_S_0295_ADNI1_MPRAGE_N3-NoSkull.nii
# Out:
# Finished

# %%
ruta_archivo = '/Result/warpped_moving.nii.gz'

imagen_nifti = nib.load(ruta_archivo)
datos_imagen = imagen_nifti.get_fdata()

print('Archivo descomprimido y cargado en la variable imagen_nifti.')
# Out:
# Archivo descomprimido y cargado en la variable imagen_nifti.

# %%
import neurite as ne
vol_shape = (176, 208, 176)

mid_slices_datos_imagen = [np.take(datos_imagen, vol_shape[d]//2, axis=d) for d in range(3)]
mid_slices_datos_imagen[1] = np.rot90(mid_slices_datos_imagen[1], 1)
mid_slices_datos_imagen[2] = np.rot90(mid_slices_datos_imagen[2], -1)
mid_slices_datos_imagen[0] = np.transpose(mid_slices_datos_imagen[0], (1, 0))
mid_slices_datos_imagen[0] = np.rot90(mid_slices_datos_imagen[0], -1)
mid_slices_datos_imagen[0] = np.rot90(mid_slices_datos_imagen[0], -1)
mid_slices_datos_imagen[2] = np.flipud(mid_slices_datos_imagen[2])

ne.plot.slices(mid_slices_datos_imagen, cmaps=['gray'], do_colorbars=True);

# %%
ruta_archivo = '/Result/warpped_flow.nii.gz'

imagen_nifti = nib.load(ruta_archivo)
datos_imagen = imagen_nifti.get_fdata()

datos_imagen.shape
# Out:
# (1, 176, 208, 176, 3)

# %%
imagenA = nib.load('/content/drive/MyDrive/pruebasTFG/002_S_0295_ADNI1_MPRAGE_N3-NoSkull.nii').get_fdata()
imagenA = (imagenA - np.min(imagenA)) / (np.max(imagenA) - np.min(imagenA))

imagenB = nib.load('/content/drive/MyDrive/pruebasTFG/002_S_0619_ADNI1_MPRAGE_N3-NoSkull.nii').get_fdata()
imagenB = (imagenB - np.min(imagenB)) / (np.max(imagenB) - np.min(imagenB))

# %%
imagenA = imagenA[..., np.newaxis]
imagenA = imagenA[np.newaxis, ...]
imagenA.shape
imagenB = imagenB[..., np.newaxis]
imagenB = imagenB[np.newaxis, ...]
imagenB.shape
datos_imagen = datos_imagen[..., np.newaxis]
datos_imagen = datos_imagen[np.newaxis, ...]
datos_imagen.shape
# Out:
# (1, 176, 208, 176, 1)

# %%
imagenA.shape
# Out:
# (1, 176, 208, 176, 1)

# %%
imagenB.shape
# Out:
# (1, 176, 208, 176, 1)

# %%
datos_imagen.shape
# Out:
# (176, 208, 176)

# %%
moving = imagenA
fixed = imagenB
warped = datos_imagen

clim = 0.5

img = moving - fixed

img1 = img[0, 100, :, :,0]
img2 = img[0, :, 100, :,0]
img3 = img[0, :, :, 100,0]

img2 = np.rot90(img2, 1)
img3 = np.rot90(img3, -1)
img1 = np.transpose(img1, (1, 0))
img1 = np.rot90(img1, -1)
img1 = np.rot90(img1, -1)
img3 = np.flipud(img3)

images = [img1, img2, img3]

for i in range(len(images)):
    images[i] = np.clip(images[i], -clim, clim)

# visualize
ne.plot.slices(images, cmaps=['gray'], do_colorbars=True);


img = warped - fixed

img1 = img[0, 100, :, :,0]
img2 = img[0, :, 100, :,0]
img3 = img[0, :, :, 100,0]

img2 = np.rot90(img2, 1)
img3 = np.rot90(img3, -1)
img1 = np.transpose(img1, (1, 0))
img1 = np.rot90(img1, -1)
img1 = np.rot90(img1, -1)
img3 = np.flipud(img3)

images = [img1, img2, img3]

for i in range(len(images)):
    images[i] = np.clip(images[i], -clim, clim)

# visualize
ne.plot.slices(images, cmaps=['gray'], do_colorbars=True);

# %%
import scipy.io as sio
sio.savemat('/content/drive/MyDrive/pruebasTFG/warp_LapIRN.mat', {'warp_LapIRN': warp1})

# %%
import scipy.io as sio
sio.savemat('/content/drive/MyDrive/pruebasTFG/warped_LapIRN.mat', {'warped_LapIRN': datos_imagen})
